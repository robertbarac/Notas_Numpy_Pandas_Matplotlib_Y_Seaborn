# %% [markdown]
# <a href="https://colab.research.google.com/github/robertbarac/Notas_Numpy_Pandas_Matplotlib_Y_Seaborn/blob/main/Apuntes_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pyplot Básico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
plt.plot(x, y)
plt.show()

# %%
#Cambiar color
plt.plot(x, y, 'r')
plt.show()

# %%
#Cambiar color
plt.plot(x, y, 'ro')
plt.show()

# %%
#Cambiar color
plt.plot(x, y, 'rs-')
plt.show()

# %%
#Cambiar color
plt.plot(x, y, 'bs-')
plt.show()

# %%
#Cambiar color
plt.plot(x, y, 'yD:')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# #Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
# Primer número: filas, segundo número: columnas, tercer número: índice del gráfico en cuestión
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r--')

plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r--')
plt.plot(y,x, 'b:')

plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y, 'r--')
plt.plot(y,x, 'b:')
#plt.xlabel("oye")

plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %% [markdown]
# #Método orientado a objetos

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig = plt.figure()
# los dos primeros valores/parámetros corresponden a la posición de inicion de la línea
# los otros dos parámetros es las dimensiones del gráfico
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes.plot(x, y, 'b')
fig.show()

# %%
fig = plt.figure()
# los dos primeros valores/parámetros corresponden a la posición de inicion de la línea
# los otros dos parámetros es las dimensiones del gráfico
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes.plot(x, y, 'b')
axes2.plot(y, x, 'r')
axes2.set_facecolor('cyan')
fig.show()

# %% [markdown]
# # Subplots

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x, y), 'b'
# Out:
# ([<matplotlib.lines.Line2D at 0x7f25c4699090>], 'b')

# %%
# nrows ws número de filas
# ncols es número de columnas, fácil
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y, 'b')
axes[1].plot(y, x, 'r')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y, 'b')
ax2.plot(y, x, 'r')

# %%
fig, axes = plt.subplots(2, 4)
axes[0,0].plot(x, np.cos(x))
axes[0,1].plot(x, np.sin(x), 'y')
axes[0,2].plot(x, np.tan(x), 'r')
axes[0,3].plot(x, np.tanh(x), 'g')

# %%
fig, ((ax1 , ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4)
ax1.plot(x, np.cos(x))
ax2.plot(x, np.sin(x), 'y')
ax3.plot(x, np.tan(x), 'r')
ax4.plot(x, np.tanh(x), 'g')
ax5.plot(x, x**2)
ax6.plot(x, 1/x, 'y')
ax7.plot(x, x**(1/2), 'r')
ax8.plot(x, np.sinh(x), 'g')
fig.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys

# %% [markdown]
# # Leyendas, etiquetas, títulos, tamaño.

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2)
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig, axes = plt.subplots(1,2, figsize=(5,5))
axes[0].plot(x,y)
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
fig, axes = plt.subplots(1,2, figsize=(5,5))
axes[0].plot(x,y, 'r', label="$sin(x)$")
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()

axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
#lo contrario de OO...
plt.plot(x, y, label= 'sin(x)')
plt.title('este es un titulo')
plt.xlabel='x'
plt.ylabel='y'
plt.legend(loc='lower left')
#plt.legend(loc='lower right')
#plt.legend(loc='upper left')
#plt.legend(loc='lower right')

# %%
plt.plot(x, y, label= 'sin(x)')
plt.title('este es un titulo')
plt.xlabel='x'
plt.ylabel='y'
plt.legend(loc='lower left', bbox_to_anchor=(1, 0.5))
#plt.legend(loc='lower right')
#plt.legend(loc='upper left')
#plt.legend(loc='lower right')

# %% [markdown]
# # Colores y Estilos

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('bmh')

# %%
fig , ax = plt.subplots(figsize=(8,8))

# %%
plt.style.use('classic')
fig , ax = plt.subplots(figsize=(8,8))

# %%
plt.style.use('fivethirtyeight')
fig , ax = plt.subplots(figsize=(8,8))

# %%
plt.style.use('dark_background')
fig , ax = plt.subplots(figsize=(8,8))

ax.plot(x, x+1, 'r--')
ax.plot(x, x+2, 'b-')
ax.plot(x, x+3, 'y.-')
ax.plot(x, x+4, 'go:')

# %% [markdown]
# **con Pyplot...**

# %%
plt.style.use('dark_background')
fig , ax = plt.subplots(figsize=(8,8))

#alpha es para transparencia, más bajo, más transparente
#linewidth es grosor de la línea, acpeta enteros...
ax.plot(x, x+1, color='green', alpha = 0.8, linewidth=5, linestyle='-', marker= 'o',
        markersize=10, markerfacecolor='#CCFFCC')
ax.plot(x, x+2, color='blue', linewidth=8, linestyle='-', marker= 'x')
ax.plot(x, x+3, color='#66FF66', linewidth=3, linestyle='dashed', marker= 'v')
ax.plot(x, x+4, color='#CCFFCC', linewidth=2, linestyle=':', marker= 'P')

# %% [markdown]
# # BarPlot

# %%
x = country = ['india', 'japan', 'mexico', 'colombia', 'germany']
population = [1000, 200, 160, 50, 40]

# %%
plt.bar(country, population, width=0.5, color=['red', 'blue']) # width es para el ancho de la barra
# color es para alternar visualmente entre el color de la barra del país.
plt.xticks(np.arange(5),('India', 'Japón', 'Mexico', 'Colombia', 'Alemania'), rotation=45)
plt.yticks(rotation=45)
plt.title('Robert')
plt.xlabel = 'País'
plt.ylabel = 'Poblacion'
plt.show()

# %%
plt.barh(country, population) # width es para el ancho de la barra
# color es para alternar visualmente entre el color de la barra del país.
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title('Robert')
plt.xlabel = 'País'
plt.ylabel = 'Poblacion'
plt.show()

# %% [markdown]
# # Crear Otro Tipo de Gráficas

# %%
data = np.random.randint(1,50,100)

# %% [markdown]
# **Histograma**

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins=50)
plt.show()

# %%
plt.hist(data, bins=10, width=5)
plt.show()

# %%
plt.hist(data, bins=10, histtype='bar')
plt.show()

# %%
plt.hist(data, bins=10, histtype='step')
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data, vert=False)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
data = np.append(data, 200)
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=True)
plt.show()

# %% [markdown]
# **Scatter**

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) ** 2
colors = np.random.rand(N)

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.scatter(x, y, s = area)
plt.show()

# %%
plt.scatter(x, y, s= area, c=colors)
plt.show()

# %%
plt.scatter(x, y, s= area, c=colors, marker='o', alpha=0.5)
plt.show()

# %%
plt.scatter(x, y, s= area, c=colors, marker='P', alpha=0.5)
plt.show()

# %%
plt.scatter(x, y, s= area, c=colors, marker='p', alpha=0.5)
plt.show()
